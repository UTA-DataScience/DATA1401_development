# %% [markdown]
# ## Topics by week:
#
# **Assuming 1 hour 20 min for class and 1 hour 50 min for lab**
#
# **All lectures, labs, HW and test can be in.ipynb format and stored on GitHub. Students can always download notebooks from GitHub and run them locally, "does not load" is not a problem**
#
# * Week1
# Class 1: How computers work
# Class 2: How computers work
# Lab 1: Software Set-up: Anaconda, Sublime, GitBash
# HW 1:
#
#
# * Week2
# Class 1: Linux/bash: basic - pwd, cd, mkdir, touch, cp, mv, rm, cat
# Class 2: Linux/bash: text file manipulations, shell scripts?
# Lab 2: Linux, Git/GitHub/
# HW 2:
#
#
# * Week3
# Class 1: Jupyter notebook, python as calculator
# **start with showing an awesome python script** that means nothing to them yet but does cool things - this is a script that should motivate them to learn python and a glance at what they will be able to do at the end of the course.
# Class 2: Simple data types:  int, float, strings
# Lab 3: Practice
# HW 3:
#
#
# * Week4
# Class 1:  Composite data types/data structures
# list, tuple, dictionary, set
# Class 2: list, tuple, dictionary, set
# Lab 4: Practice
# HW 4:
#
#
# * Week5
# Class 1: Control structures
# if,elif loops, break, continue
# Class 2: List and dictionary comprehensions
# Lab 5: Practice:
# `for w in words[:]:
#      words.insert(1,w)`
# -good for understanding loops/list copies
# HW 5:
#
#
# * Week6
# Class 1:  Functions:built-in, user-defined
# Class 2:  Functions-lambda, map, filter
# Lab 6: Practice
# HW 6:
#
#
# * Week7
# Class 1: User-defined types: Classes/attributes
# Class 2: Classes/methods
# Lab 7: Practice
# HW 7:
#
#
# * Week8
# Class 1: Classes: Inheritance
# Class 2: Classes: Polymorphism
# Lab 8: Practice
# HW 8:
#
#
# * Week9
# Class 1: packages, modules, file IO
# Class 2: packages: matplotlib
# Lab 9: Practice: data visualization
# HW 9:
#
#
# * Week10
# Class 1: packages: numpy
# Class 2: packages: numpy
# Lab 10: Practice: matrix operations
# HW 10:
#
#
# * Week11
# Class 1: packages: pandas
# Class 2: packages: pandas
# Lab 11: Practice: pandas
# HW 11:
#
#
# * Week12
# Class 1: Pyhon scripts
# Class 2: Python scripts
# Lab 12: Practice
# HW 12:
#
#
# * Week13
# Class 1: optimizing code: error handling, debugging
# Class 2: optimizing code: deque, timeit
# Lab 13: Practice
# HW 13:
#
#
# * Week 14
# Class 1: An awesome script that incorporated everything we covered in class.
# Class 2: An awesome script that incorporated everything we covered in class.
# Lab 14:
#
#
# **Labs:** include data science interview questions
